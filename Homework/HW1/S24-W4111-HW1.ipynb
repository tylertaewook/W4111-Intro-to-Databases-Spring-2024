# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# loud {
#     font-size: 20pt;
#     }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
# </style>
#
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# COMS W4111: Introduction to Databases<br>
# Spring 2024, Sections 002/V02
# </span>
# </center></b>
# <br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2">
# Homework 1<br>Introduction to Core Concepts, ER Modeling, Relational Algebra, SQL<br>
# </span>
# </center></i>

# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook contains Homework 1. **Both Programming and Nonprogramming tracks should complete this homework.**

# %% [markdown]
# # Submission Instructions

# %% [markdown]
# - You will submit **PDF and ZIP files** for this assignment. Gradescope will have two separate assignments for these.
# - For the PDF:
#     - The most reliable way to save as PDF is to go to your browser's menu bar and click `File -> Print`. Switch the orientation to landscape mode, and hit save.
#     - **MAKE SURE ALL YOUR WORK (CODE AND SCREENSHOTS) IS VISIBLE ON THE PDF. YOU WILL NOT GET CREDIT IF ANYTHING IS CUT OFF.** Reach out for troubleshooting.
#     - **MAKE SURE YOU DON'T SUBMIT A SINGLE PAGE PDF.** Your PDF should have multiple pages.
# - For the ZIP:
#     - Zip a folder containing this notebook and any screenshots.
#     - You may delete any unnecessary files, such as caches.

# %% [markdown]
# <hr style="height:2px;">

# %% [markdown]
# # Add Student Information

# %%
# Print your name, uni, and track below

name = "Tyler Kim"
uni = "tk2891"
track = "Programming Track"

print(name)
print(uni)
print(track)
# Out:
# Tyler Kim
# tk2891
# Programming Track

# %% [markdown]
# # Setup

# %% [markdown]
# ## SQL Magic

# %% [markdown]
# The `sql` extension was installed in HW0. Double check that if this cell doesn't work.

# %%
# %load_ext sql

# %% [markdown]
# You may need to change the password below.

# %%
# %sql mysql+pymysql://root:dbuserdbuser@localhost

# %%
# %sql SELECT * FROM db_book.student WHERE ID = 12345
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [('12345', 'Shankar', 'Comp. Sci.', Decimal('32'))]

# %% [markdown]
# ## Python Libraries

# %%
from IPython.display import Image
import pandas

# %% [markdown]
# <hr style="height:2px;">

# %% [markdown]
# # Written Questions
#
# Chapter 1 from the recommended textbook [Database System Concepts, Seventh Edition](https://codex.cs.yale.edu/avi/db-book/) covers general information and concepts about databases and database management systems. Lecturing on the general and background information is not a good use of precious class time. To be more efficient with class time, the chapter 1 information is a reading assignment.
#
# Answering the written questions in HW 1, Part 1 does not require purchasing the textbook and reading the chapter. The [chapter 1 slides](https://codex.cs.yale.edu/avi/db-book/slides-dir/index.html) provided by the textbook authors provide the necessary information. In some cases, students may also have to search the web or other sources to “read” the necessary information.
#
# When answering the written questions, do not “bloviate”. The quantity of words does not correlate with the quality of the answer. We will deduct points if you are not succinct. The answers to the questions require less than five sentences or bullet points.
#
# ### “If you can't explain something in a few words, try fewer.”
#
# You may use external resources, but you should cite your sources.

# %% [markdown]
# ## W1
#
# What is a database management system and how do relational databases organize data?
#
# Database Management System is a software to manage a database, ensuring that data is consistently organized and remains easily accessible. Their core features include concurrent access, data storage/retrieval, and the management of database security, integrity, and transaction processing.
#
# Relational Database organize data into tables that are linked with relationships, which allows them to handle complex queries over various data types.

# %% [markdown]
# ## W2
#
# Columbia University uses several applications that use databases to run the university. Examples are SSOL and CourseWorks. An alternate approach could be letting students, faculty, administrators, etc. use shared Google Sheets to create, retrieve, update, and delete information. What are some problems with the shared spread sheet approach and what functions do DMBS implement to solve the problems?
#
# Shared spread sheet approach can lead to problems in data redundancy/inconsistency, insufficient security and access controls, and difficulty in accessing data.
#
# DMBS can solve these problems in order using normalization, role-based access control, and SQL for efficient data querying and manipulation.

# %% [markdown]
# ## W3
#
# Explain the differences between SQL, MySQL Server and DataGrip.
#
# 1. SQL is a structured query **language** designed to manage, access, and manipulate relational databases.
# 2. MySQL Server is a type of **database system** that uses SQL as a query language
# 3. DataGrip is an **integrated development environment** (IDE) designed for database administration and development beyond MySQL

# %% [markdown]
# ## W4
#
# Crow’s Foot Notation has four endings for relationship lines. Briefly explain the meaning of each ending.
#
# <img src="./CFN.png">
#
# 1. zero or one
#
# 2. one and only one
#
# 3. zero or many
#
# 4. one of many

# %% [markdown]
# ## W5
#
# What is a primary key and why is it important?
#
# A primary key is a specific column in a table that uniquely identifies each record within the table.
# It is important because it ensures each record is unique, as no two rows can have the same primary key value. It also plays a critical role in establishing relationships between tables.

# %% [markdown]
# ## W6
#
# The relational algebra is closed under the operators. Explain what this means and give an example.
#
# Being closed under the operators mean that whenever you perform an operation like sorting, combining, or filtering data in tables, you always end up with a new table. This is useful because it means you can keep using these operations in steps, one after another, to organize or find data the way you need.
#
# For example, consider the relation named `Students`.
#
# If we apply the projection operation on the Students relation to select only the Name column, the the output of the projection operation is another relation with a single column Name containing the names of all students. This allows further relational algebra operations to be applied if desired.

# %% [markdown]
# ## W7
#
# Some of the Columbia University databases/applications represent the year/semester attribute of a section in the form "2023_2". The first four characters are the academic year, and the last character is the semester (1, 2, or 3). The data type for this attribute might be CHAR(6). Using this example, explain the concepts of domain and atomic domain. How is domain different from type?
#
# - Domain refers to the set of all possible valid values an attribute can take, constrained by specific rules. For the "2023_2" attribute at Columbia University, the domain limits values to a pattern representing academic periods.
# - Atomic Domain means each value in the domain is indivisible. In the "2023_2" example, the entire string, including the year and semester, is treated as a single, undividable piece of data.
# - The type (e.g., CHAR(6)) specifies the data format, while the domain applies constraints within that type to define valid data for an attribute, ensuring data integrity and consistency.

# %% [markdown]
# ## W8
#
# Briefly explain the difference between a database schema and database instance.
#
# Database schema is the overall logical/physical structure of the database, where database instance is the actual content dictated by these schema at a particular point in time.

# %% [markdown]
# ## W9
#
# Briefly explain the concepts of data definition language and data manipulation language.
#
# 1. DDL: specification notation for defining the database schema
# 2. DML: language for accessing and maniputaling the data organized by an data model, such as SQL.

# %% [markdown]
# ## W10
#
# What is physical data independence?
#
# Physical data independence is the ability to modify the physical schema without changing the logical schema. This nature allows administrators to optimize and reorganize the physical layout of data for performance improvements without impacting application functionality.

# %% [markdown]
# <hr style="height:2px;">

# %% [markdown]
# # Entity-Relationship Modeling

# %% [markdown]
# ## Overview

# %% [markdown]
# The ability to understand a general description of a requested data model and to transform into a more precise, specified _logical model_ is one of the most important skills for using databases. SW and data engineers build applications and data models for end-users. The end-users, product managers and business managers are not SW or data modeling experts. They will express their _intent_ in imprecise, text and words.
#
# The users and business stakeholder often can understand and interact using a _conceptual model_ but details like keys, foreign keys, ... are outside their scope.
#
# In this problem, you will:
# - Understand a short written description of a requested data model.
# - Produce a _conceptual data model diagram_ using Lucidchart.
# - Produce a _logical data model diagram_ using Lucidchart.
#
# You can sign up for a free [Lucidchart account.](https://www.lucidchart.com/pages/landing) The free account provides the capabilities you will need for this course.
#
# To draw the diagrams, you need to add the _entity relationship_ shapes. Lecture 2 demonstrated how to add the shapes.

# %% [markdown]
# | <img src="./lucidchart.jpg"> |
# | :---: |
# | __Adding Entity Relationship Shapes__|

# %% [markdown]
# We provide a simple [Lucidchart document](https://lucid.app/lucidchart/828777b1-7b2d-4828-bedb-37b6d456c33e/edit?invitationId=inv_a142899a-7e60-44e9-b18e-335d7c9767fc) from Lecture 2 that helps you get started. You need a Lucidchart account to access the document and diagrams.

# %% [markdown]
# ## Data Model Description

# %% [markdown]
# The data model represents banks, customers. employees and accouts. The model has the following entity types/sets:
# 1. _Customer_
# 2. _Employee_ of the banking company
# 3. _Branch,_ which is a location of one of the banks offices
# 4. _Savings Account_
# 5. _Checking Account_
# 6. _Loan_
# 7. _Portfolio_
#
#
# _Customer_ has the following properties:
# - _customerID_
# - _lastName_
# - _firstName_
# - _email_
# - _dateOfBirth_
#
#
# _Employee_ has the following properties:
# - _employeeID_
# - _lastName_
# - _firstName_
# - _jobTitle_
#
#
# _Branch_ has the following properties:
# - _branchID_
# - _zipCode_
#
#
# _Savings Account_ has the following properties:
# - _accountID_
# - _balance_
# - _interestRate_
#
#
# _Checking Account_ has the following properties:
# - _accountID_
# - _balance_
#
#
# _Loan_ has the following properties.
# - _loanID_
# - _balance_
# - _interestRate_
#
#
# _Portfolio_ has the following properties:
# - _portfolioID_
# - _createdDate_

# %% [markdown]
# The data model has the following relationships:
# - _Customer Branch_ connects a customer and a branch. A _Customer_ is connected to exactly one _Branch_. A _Branch_ may have 0, 1 or many customers.
# - _Employee Branch_ connects an employee and a branch. An _Employee_ is connected to exactly one _Branch_. A _Branch_ may have 0, 1 or many associated employees.
# - _Savings Account Branch_, _Checking Account Branch_, and _Loan Branch_ all have the same pattern.
#     - An account/loan has exactly one branch.
#     - A _Branch_ many have 0, 1 or many accounts/loans.
# - _Savings Customer_, _Checking Customer_, _Loan Customer_, and _Portfolio Customer_ follow the same pattern.
#     - The account/loan has exactly one customer.
#     - The customer may have 0 or 1 of each type of account.
# - A _Portfolio_ is related to exactly one _Customer_, exactly one _Savings Account_, exactly one _Checking Account_, and exactly one _Loan_.
# - _Portfolio Advisor_ relates a _Portfolio_ and _Employee_. An _Employee_ may be the advisor for 0, 1 or many _Portfolios_. A _Portfolio_ may have at most one _Employee_ advisor.

# %% [markdown]
# ## Answer
#
# 1. Place your Logical Model diagram below.
# 2. You _may_ have to add attributes to entities to implement the model.
# 3. You _may_ make reasonable assumptions. Please document your assumptions below. You may add comments/notes to your diagram for clarity.

# %% [markdown]
# Assumptions:
# 1. Each relation between the Portfolio and one of Customer, Savings Account, Checking Account, and Loan is an relation that is exactly one to each other.

# %% [markdown]
# ER Diagram:
#
# Save your diagram to an image, place in the same directory as your notebook and change the file name in the HTML ```img``` tag in this Markdown cell.
#
# | <img src="./diagram.png"> |
# | :---: |
# | __Logical ER Diagram__|

# %% [markdown]
# # Relational Algebra

# %% [markdown]
# ## R-1

# %% [markdown]
# The following is the SQL DDL for the `db_book.classroom` table.
#
# ```
# CREATE TABLE IF NOT EXISTS db_book.classroom
# (
#     building    VARCHAR(15) NOT NULL,
#     room_number VARCHAR(7)  NOT NULL,
#     capacity    DECIMAL(4)  NULL,
#     PRIMARY KEY (building, room_number)
# );
# ```
#
# Using the notation from the lecture slides, provide the corresponding relation schema definition.

# %% [markdown]
# ## Answer Format

# %% [markdown]
# For the answers to the relational algebra questions, you will use the [RelaX calculator](https://dbis-uibk.github.io/relax/calc/gist/4f7866c17624ca9dfa85ed2482078be8/relax-silberschatz-english.txt/0) with the schema associated with the book. You answer should include the algebra statement in as text and a screenshot of the execution result. Question __R0__ below shows a sample of that the answer will look like.

# %% [markdown]
# ## R0

# %% [markdown]
# Write a relational algebra statement that produces a table of the following form:
# - ID is the instructor ID
# - name is the instructor name
# - course_id, sec_id, semester, year of a section
# - building, room_number
#
# __Note:__
# 1. You will have to use the instructor, teaches and section relations
# 2. Your answer should only include sections taught in ```Comp. Sci.``` in ```2009```

# %% [markdown]
# Algebra statement:
#
# ```
# π ID, name, course_id, sec_id, semester, year, building, room_number(
# 	(σ dept_name='Comp. Sci.' ∧ year=2009
# 		(teaches ⨝ instructor)
# 		)
# ⨝ section)
# ```

# %% [markdown]
# Execution:
#
# | <img src="./R0-sample.jpg"> |
# | :---: |
# | __RO Execution Result__|

# %% [markdown]
# ## R1

# %% [markdown]
# Write a relational algebra statement that produces a relation with the columns:
#
# - `student.name`
# - `student.dept_name`
# - `student.tot_cred`
# - `instructor.name` (the instructor that advises the student)
# - `instructor.dept_name`
#
# Only keep students who have earned more than 90 credits.
#
# __Note:__
# 1. You will have to use the `student`, `instructor`, and `advisor` relations.
# 2. You should only include students that have an advisor, i.e., `instructor.name` and `instructor.dept_name` should be non-null for all rows.

# %% [markdown]
# Algebra statement:
#
# ```
# π student.name, student.dept_name, student.tot_cred, instructor.name, instructor.dept_name
# (
#     σ student.tot_cred > 90 (student)
#     ⨝ student.ID = advisor.s_id (advisor)
#     ⨝ advisor.i_id = instructor.ID (instructor)
# )
#
# ```

# %% [markdown]
# Execution:
#
# | <img src="./R1.png"> |
# | :---: |
# | __R1 Execution Result__|

# %% [markdown]
# ## R2

# %% [markdown]
# Write a relational algebra statement that produces a relation with the columns:
#
# * `course_id`
# * `title`
# * `prereq_course_id`
# * `prereq_course_title`
#
# This relation represents courses and their prereqs.
#
# __Note:__
# 1. This query requires the ```course``` and ```prereq``` tables.
# 2. Your answer should only include courses in the `Comp. Sci.` department.
# 2. If a course has no prereqs, `prereq_course_id` and `prereq_course_title` should both be *null*.
# 3. You _may_ have to use table and column renaming.

# %% [markdown]
# Algebra statement:
#
# ```
# A =
#
#
# π course_id, title, prereq_course_id, prereq_course_title
# (
#     σ student.tot_cred > 90 (student)
#     ⨝ student.ID = advisor.s_id (advisor)
#     ⨝ advisor.i_id = instructor.ID (instructor)
# )
# ```

# %% [markdown]
# Execution:
#
# | Place img tag here |
# | :---: |
# | __R2 Execution Result__|

# %% [markdown]
# # SQL

# %% [markdown]
# ## New Database

# %% [markdown]
# [MySQL Tutorial](https://www.mysqltutorial.org/) is a good site with information that complements and extends the core material in our course. Much of the material the site covers is applicable to other SQL products. MySQL Tutorial uses an interesting dataset that is more complex than the simple "db_book" database. This is the [Classic Models Dataset](https://www.mysqltutorial.org/getting-started-with-mysql/mysql-sample-database/). The complexity allows us to better appreciate more complex SQL concepts.
#
#
# You learned how to run a SQL script/file as part of HW0. **Use the same approach to load and create the ```Classic Models Database```.** The file is ```classic-models-database.sql``` and is in the HW1 folder.
#
#
# To test loading the data, you can use the cell below.

# %%
# %sql mysql+pymysql://root:dbuserdbuser@localhost

# %%
# %sql show tables;
# Out:
#  * mysql+pymysql://root:***@localhost
# (pymysql.err.OperationalError) (1046, 'No database selected')
# [SQL: show tables;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql USE classicmodels;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# ## SQL 1

# %% [markdown]
# This query uses `customers` and `employees`.
#
# Write and execute a SQL query that produces a table with the following columns:
#
# - `customerContactName`
# - `customerPhone`
# - `salesRepName`
#
# Only keep customers from France. Order your output by `customerContactName`.
#
# Notes:
# - The names of your columns must match exactly with what is specified.
# - `customerContactName` can be formed by combining `customers.contactFirstName` and `customers.contactLastName`.
# - `salesRepName` can be formed by combining `employees.firstName` and `employees.lastName`.

# %%
# %%sql
#
# SELECT
#     CONCAT(customers.contactFirstName, ' ', customers.contactLastName) AS customerContactName,
#     CONCAT(employees.firstName, ' ', employees.lastName) AS salesRepName,
#     customers.phone AS customerPhone
# FROM customers, employees
# ORDER BY customerContactName;
# Out:
#  * mysql+pymysql://root:***@localhost
# 2806 rows affected.
# [('Adrian Huxley', 'Diane Murphy', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Mary Patterson', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Jeff Firrelli', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'William Patterson', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Gerard Bondur', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Anthony Bow', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Leslie Jennings', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Leslie Thompson', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Julie Firrelli', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Steve Patterson', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Foon Yue Tseng', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'George Vanauf', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Loui Bondur', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Gerard Hernandez', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Pamela Castillo', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Larry Bott', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Barry Jones', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Andy Fixter', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Peter Marsh', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Tom King', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Mami Nishi', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Yoshimi Kato', '+61 2 9495 8555'),
#  ('Adrian Huxley', 'Martin Gerard', '+61 2 9495 8555'),
#  ('Akiko Shimamura', 'Diane Murphy', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Loui Bondur', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Martin Gerard', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Yoshimi Kato', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Mami Nishi', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Tom King', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Peter Marsh', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Andy Fixter', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Barry Jones', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Larry Bott', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Pamela Castillo', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Gerard Hernandez', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'George Vanauf', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Foon Yue Tseng', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Steve Patterson', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Julie Firrelli', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Leslie Thompson', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Leslie Jennings', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Anthony Bow', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Gerard Bondur', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'William Patterson', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Jeff Firrelli', '+81 3 3584 0555'),
#  ('Akiko Shimamura', 'Mary Patterson', '+81 3 3584 0555'),
#  ('Alejandra  Camino', 'George Vanauf', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Martin Gerard', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Yoshimi Kato', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Mami Nishi', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Tom King', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Peter Marsh', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Andy Fixter', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Barry Jones', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Larry Bott', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Pamela Castillo', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Gerard Hernandez', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Loui Bondur', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Diane Murphy', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Foon Yue Tseng', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Steve Patterson', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Julie Firrelli', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Leslie Thompson', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Leslie Jennings', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Anthony Bow', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Gerard Bondur', '(91) 745 6555'),
#  ('Alejandra  Camino', 'William Patterson', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Jeff Firrelli', '(91) 745 6555'),
#  ('Alejandra  Camino', 'Mary Patterson', '(91) 745 6555'),
#  ('Alexander  Feuer', 'Martin Gerard', '0342-555176'),
#  ('Alexander  Feuer', 'Yoshimi Kato', '0342-555176'),
#  ('Alexander  Feuer', 'Mami Nishi', '0342-555176'),
#  ('Alexander  Feuer', 'Tom King', '0342-555176'),
#  ('Alexander  Feuer', 'Peter Marsh', '0342-555176'),
#  ('Alexander  Feuer', 'Andy Fixter', '0342-555176'),
#  ('Alexander  Feuer', 'Barry Jones', '0342-555176'),
#  ('Alexander  Feuer', 'Larry Bott', '0342-555176'),
#  ('Alexander  Feuer', 'Pamela Castillo', '0342-555176'),
#  ('Alexander  Feuer', 'Gerard Hernandez', '0342-555176'),
#  ('Alexander  Feuer', 'Loui Bondur', '0342-555176'),
#  ('Alexander  Feuer', 'George Vanauf', '0342-555176'),
#  ('Alexander  Feuer', 'Foon Yue Tseng', '0342-555176'),
#  ('Alexander  Feuer', 'Steve Patterson', '0342-555176'),
#  ('Alexander  Feuer', 'Julie Firrelli', '0342-555176'),
#  ('Alexander  Feuer', 'Leslie Thompson', '0342-555176'),
#  ('Alexander  Feuer', 'Leslie Jennings', '0342-555176'),
#  ('Alexander  Feuer', 'Anthony Bow', '0342-555176'),
#  ('Alexander  Feuer', 'Gerard Bondur', '0342-555176'),
#  ('Alexander  Feuer', 'William Patterson', '0342-555176'),
#  ('Alexander  Feuer', 'Jeff Firrelli', '0342-555176'),
#  ('Alexander  Feuer', 'Mary Patterson', '0342-555176'),
#  ('Alexander  Feuer', 'Diane Murphy', '0342-555176'),
#  ('Alexander  Semenov', 'Mary Patterson', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Diane Murphy', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'William Patterson', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Gerard Bondur', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Anthony Bow', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Leslie Jennings', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Leslie Thompson', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Julie Firrelli', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Steve Patterson', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Foon Yue Tseng', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'George Vanauf', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Loui Bondur', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Gerard Hernandez', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Pamela Castillo', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Larry Bott', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Barry Jones', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Andy Fixter', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Peter Marsh', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Tom King', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Mami Nishi', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Yoshimi Kato', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Martin Gerard', '+7 812 293 0521'),
#  ('Alexander  Semenov', 'Jeff Firrelli', '+7 812 293 0521'),
#  ('Allen Nelson', 'Jeff Firrelli', '6175558555'),
#  ('Allen Nelson', 'William Patterson', '6175558555'),
#  ('Allen Nelson', 'Gerard Bondur', '6175558555'),
#  ('Allen Nelson', 'Anthony Bow', '6175558555'),
#  ('Allen Nelson', 'Leslie Jennings', '6175558555'),
#  ('Allen Nelson', 'Leslie Thompson', '6175558555'),
#  ('Allen Nelson', 'Julie Firrelli', '6175558555'),
#  ('Allen Nelson', 'Steve Patterson', '6175558555'),
#  ('Allen Nelson', 'Foon Yue Tseng', '6175558555'),
#  ('Allen Nelson', 'George Vanauf', '6175558555'),
#  ('Allen Nelson', 'Loui Bondur', '6175558555'),
#  ('Allen Nelson', 'Gerard Hernandez', '6175558555'),
#  ('Allen Nelson', 'Diane Murphy', '6175558555'),
#  ('Allen Nelson', 'Pamela Castillo', '6175558555'),
#  ('Allen Nelson', 'Larry Bott', '6175558555'),
#  ('Allen Nelson', 'Barry Jones', '6175558555'),
#  ('Allen Nelson', 'Andy Fixter', '6175558555'),
#  ('Allen Nelson', 'Peter Marsh', '6175558555'),
#  ('Allen Nelson', 'Tom King', '6175558555'),
#  ('Allen Nelson', 'Mami Nishi', '6175558555'),
#  ('Allen Nelson', 'Yoshimi Kato', '6175558555'),
#  ('Allen Nelson', 'Martin Gerard', '6175558555'),
#  ('Allen Nelson', 'Mary Patterson', '6175558555'),
#  ('Ann  Brown', 'Martin Gerard', '(171) 555-0297'),
#  ('Ann  Brown', 'Yoshimi Kato', '(171) 555-0297'),
#  ('Ann  Brown', 'Mami Nishi', '(171) 555-0297'),
#  ('Ann  Brown', 'Tom King', '(171) 555-0297'),
#  ('Ann  Brown', 'Peter Marsh', '(171) 555-0297'),
#  ('Ann  Brown', 'Andy Fixter', '(171) 555-0297'),
#  ('Ann  Brown', 'Barry Jones', '(171) 555-0297'),
#  ('Ann  Brown', 'Larry Bott', '(171) 555-0297'),
#  ('Ann  Brown', 'Pamela Castillo', '(171) 555-0297'),
#  ('Ann  Brown', 'Gerard Hernandez', '(171) 555-0297'),
#  ('Ann  Brown', 'Loui Bondur', '(171) 555-0297'),
#  ('Ann  Brown', 'George Vanauf', '(171) 555-0297'),
#  ('Ann  Brown', 'Foon Yue Tseng', '(171) 555-0297'),
#  ('Ann  Brown', 'Steve Patterson', '(171) 555-0297'),
#  ('Ann  Brown', 'Julie Firrelli', '(171) 555-0297'),
#  ('Ann  Brown', 'Leslie Thompson', '(171) 555-0297'),
#  ('Ann  Brown', 'Leslie Jennings', '(171) 555-0297'),
#  ('Ann  Brown', 'Anthony Bow', '(171) 555-0297'),
#  ('Ann  Brown', 'Gerard Bondur', '(171) 555-0297'),
#  ('Ann  Brown', 'William Patterson', '(171) 555-0297'),
#  ('Ann  Brown', 'Jeff Firrelli', '(171) 555-0297'),
#  ('Ann  Brown', 'Mary Patterson', '(171) 555-0297'),
#  ('Ann  Brown', 'Diane Murphy', '(171) 555-0297'),
#  ("Anna O'Hara", 'Jeff Firrelli', '02 9936 8555'),
#  ("Anna O'Hara", 'Diane Murphy', '02 9936 8555'),
#  ("Anna O'Hara", 'William Patterson', '02 9936 8555'),
#  ("Anna O'Hara", 'Gerard Bondur', '02 9936 8555'),
#  ("Anna O'Hara", 'Anthony Bow', '02 9936 8555'),
#  ("Anna O'Hara", 'Leslie Jennings', '02 9936 8555'),
#  ("Anna O'Hara", 'Leslie Thompson', '02 9936 8555'),
#  ("Anna O'Hara", 'Julie Firrelli', '02 9936 8555'),
#  ("Anna O'Hara", 'Steve Patterson', '02 9936 8555'),
#  ("Anna O'Hara", 'Foon Yue Tseng', '02 9936 8555'),
#  ("Anna O'Hara", 'George Vanauf', '02 9936 8555'),
#  ("Anna O'Hara", 'Loui Bondur', '02 9936 8555'),
#  ("Anna O'Hara", 'Gerard Hernandez', '02 9936 8555'),
#  ("Anna O'Hara", 'Pamela Castillo', '02 9936 8555'),
#  ("Anna O'Hara", 'Larry Bott', '02 9936 8555'),
#  ("Anna O'Hara", 'Barry Jones', '02 9936 8555'),
#  ("Anna O'Hara", 'Andy Fixter', '02 9936 8555'),
#  ("Anna O'Hara", 'Peter Marsh', '02 9936 8555'),
#  ("Anna O'Hara", 'Tom King', '02 9936 8555'),
#  ("Anna O'Hara", 'Mami Nishi', '02 9936 8555'),
#  ("Anna O'Hara", 'Yoshimi Kato', '02 9936 8555'),
#  ("Anna O'Hara", 'Martin Gerard', '02 9936 8555'),
#  ("Anna O'Hara", 'Mary Patterson', '02 9936 8555'),
#  ('Annette  Roulet', 'Jeff Firrelli', '61.77.6555'),
#  ('Annette  Roulet', 'Mary Patterson', '61.77.6555'),
#  ('Annette  Roulet', 'Martin Gerard', '61.77.6555'),
#  ('Annette  Roulet', 'Yoshimi Kato', '61.77.6555'),
#  ('Annette  Roulet', 'Mami Nishi', '61.77.6555'),
#  ('Annette  Roulet', 'Tom King', '61.77.6555'),
#  ('Annette  Roulet', 'Peter Marsh', '61.77.6555'),
#  ('Annette  Roulet', 'Andy Fixter', '61.77.6555'),
#  ('Annette  Roulet', 'Barry Jones', '61.77.6555'),
#  ('Annette  Roulet', 'Larry Bott', '61.77.6555'),
#  ('Annette  Roulet', 'Pamela Castillo', '61.77.6555'),
#  ('Annette  Roulet', 'Gerard Hernandez', '61.77.6555'),
#  ('Annette  Roulet', 'Loui Bondur', '61.77.6555'),
#  ('Annette  Roulet', 'George Vanauf', '61.77.6555'),
#  ('Annette  Roulet', 'Foon Yue Tseng', '61.77.6555'),
#  ('Annette  Roulet', 'Steve Patterson', '61.77.6555'),
#  ('Annette  Roulet', 'Julie Firrelli', '61.77.6555'),
#  ('Annette  Roulet', 'Leslie Thompson', '61.77.6555'),
#  ('Annette  Roulet', 'Leslie Jennings', '61.77.6555'),
#  ('Annette  Roulet', 'Anthony Bow', '61.77.6555'),
#  ('Annette  Roulet', 'Gerard Bondur', '61.77.6555'),
#  ('Annette  Roulet', 'William Patterson', '61.77.6555'),
#  ('Annette  Roulet', 'Diane Murphy', '61.77.6555'),
#  ('Armand Kuger', 'Diane Murphy', '+27 21 550 3555'),
#  ('Armand Kuger', 'Jeff Firrelli', '+27 21 550 3555'),
#  ('Armand Kuger', 'William Patterson', '+27 21 550 3555'),
#  ('Armand Kuger', 'Gerard Bondur', '+27 21 550 3555'),
#  ('Armand Kuger', 'Anthony Bow', '+27 21 550 3555'),
#  ('Armand Kuger', 'Leslie Jennings', '+27 21 550 3555'),
#  ('Armand Kuger', 'Leslie Thompson', '+27 21 550 3555'),
#  ('Armand Kuger', 'Julie Firrelli', '+27 21 550 3555'),
#  ('Armand Kuger', 'Steve Patterson', '+27 21 550 3555'),
#  ('Armand Kuger', 'Foon Yue Tseng', '+27 21 550 3555'),
#  ('Armand Kuger', 'George Vanauf', '+27 21 550 3555'),
#  ('Armand Kuger', 'Loui Bondur', '+27 21 550 3555'),
#  ('Armand Kuger', 'Gerard Hernandez', '+27 21 550 3555'),
#  ('Armand Kuger', 'Pamela Castillo', '+27 21 550 3555'),
#  ('Armand Kuger', 'Larry Bott', '+27 21 550 3555'),
#  ('Armand Kuger', 'Barry Jones', '+27 21 550 3555'),
#  ('Armand Kuger', 'Andy Fixter', '+27 21 550 3555'),
#  ('Armand Kuger', 'Peter Marsh', '+27 21 550 3555'),
#  ('Armand Kuger', 'Tom King', '+27 21 550 3555'),
#  ('Armand Kuger', 'Mami Nishi', '+27 21 550 3555'),
#  ('Armand Kuger', 'Yoshimi Kato', '+27 21 550 3555'),
#  ('Armand Kuger', 'Martin Gerard', '+27 21 550 3555'),
#  ('Armand Kuger', 'Mary Patterson', '+27 21 550 3555'),
#  ('Arnold Cruz', 'George Vanauf', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Martin Gerard', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Yoshimi Kato', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Mami Nishi', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Tom King', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Peter Marsh', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Andy Fixter', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Barry Jones', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Larry Bott', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Pamela Castillo', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Gerard Hernandez', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Loui Bondur', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Foon Yue Tseng', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Steve Patterson', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Julie Firrelli', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Leslie Thompson', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Leslie Jennings', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Anthony Bow', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Gerard Bondur', '+63 2 555 3587'),
#  ('Arnold Cruz', 'William Patterson', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Jeff Firrelli', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Mary Patterson', '+63 2 555 3587'),
#  ('Arnold Cruz', 'Diane Murphy', '+63 2 555 3587'),
#  ('Ben Calaghan', 'Mary Patterson', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Martin Gerard', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Yoshimi Kato', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Diane Murphy', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Mami Nishi', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Tom King', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Peter Marsh', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Andy Fixter', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Barry Jones', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Larry Bott', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Pamela Castillo', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Gerard Hernandez', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Loui Bondur', '61-7-3844-6555'),
#  ('Ben Calaghan', 'George Vanauf', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Foon Yue Tseng', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Steve Patterson', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Julie Firrelli', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Leslie Thompson', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Leslie Jennings', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Anthony Bow', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Gerard Bondur', '61-7-3844-6555'),
#  ('Ben Calaghan', 'William Patterson', '61-7-3844-6555'),
#  ('Ben Calaghan', 'Jeff Firrelli', '61-7-3844-6555'),
#  ('Bradley Schuyler', 'Jeff Firrelli', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Yoshimi Kato', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Mami Nishi', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Tom King', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Peter Marsh', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Andy Fixter', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Barry Jones', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Larry Bott', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Pamela Castillo', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Gerard Hernandez', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Loui Bondur', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'George Vanauf', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Foon Yue Tseng', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Steve Patterson', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Julie Firrelli', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Leslie Thompson', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Leslie Jennings', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Anthony Bow', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Gerard Bondur', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'William Patterson', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Diane Murphy', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Mary Patterson', '+31 20 491 9555'),
#  ('Bradley Schuyler', 'Martin Gerard', '+31 20 491 9555'),
#  ('Braun Urs', 'Mary Patterson', '0452-076555'),
#  ('Braun Urs', 'Diane Murphy', '0452-076555'),
#  ('Braun Urs', 'Martin Gerard', '0452-076555'),
#  ('Braun Urs', 'Jeff Firrelli', '0452-076555'),
#  ('Braun Urs', 'William Patterson', '0452-076555'),
#  ('Braun Urs', 'Gerard Bondur', '0452-076555'),
#  ('Braun Urs', 'Anthony Bow', '0452-076555'),
#  ('Braun Urs', 'Leslie Jennings', '0452-076555'),
#  ('Braun Urs', 'Leslie Thompson', '0452-076555'),
#  ('Braun Urs', 'Julie Firrelli', '0452-076555'),
#  ('Braun Urs', 'Steve Patterson', '0452-076555'),
#  ('Braun Urs', 'Foon Yue Tseng', '0452-076555'),
#  ('Braun Urs', 'George Vanauf', '0452-076555'),
#  ('Braun Urs', 'Loui Bondur', '0452-076555'),
#  ('Braun Urs', 'Gerard Hernandez', '0452-076555'),
#  ('Braun Urs', 'Pamela Castillo', '0452-076555'),
#  ('Braun Urs', 'Larry Bott', '0452-076555'),
#  ('Braun Urs', 'Barry Jones', '0452-076555'),
#  ('Braun Urs', 'Andy Fixter', '0452-076555'),
#  ('Braun Urs', 'Peter Marsh', '0452-076555'),
#  ('Braun Urs', 'Tom King', '0452-076555'),
#  ('Braun Urs', 'Mami Nishi', '0452-076555'),
#  ('Braun Urs', 'Yoshimi Kato', '0452-076555'),
#  ('Brian Chandler', 'Jeff Firrelli', '2155554369'),
#  ('Brian Chandler', 'Mary Patterson', '2155554369'),
#  ('Brian Chandler', 'William Patterson', '2155554369'),
#  ('Brian Chandler', 'Gerard Bondur', '2155554369'),
#  ('Brian Chandler', 'Anthony Bow', '2155554369'),
#  ('Brian Chandler', 'Leslie Jennings', '2155554369'),
#  ('Brian Chandler', 'Leslie Thompson', '2155554369'),
#  ('Brian Chandler', 'Julie Firrelli', '2155554369'),
#  ('Brian Chandler', 'Steve Patterson', '2155554369'),
#  ('Brian Chandler', 'Foon Yue Tseng', '2155554369'),
#  ('Brian Chandler', 'George Vanauf', '2155554369'),
#  ('Brian Chandler', 'Loui Bondur', '2155554369'),
#  ('Brian Chandler', 'Gerard Hernandez', '2155554369'),
#  ('Brian Chandler', 'Pamela Castillo', '2155554369'),
#  ('Brian Chandler', 'Larry Bott', '2155554369'),
#  ('Brian Chandler', 'Barry Jones', '2155554369'),
#  ('Brian Chandler', 'Andy Fixter', '2155554369'),
#  ('Brian Chandler', 'Peter Marsh', '2155554369'),
#  ('Brian Chandler', 'Tom King', '2155554369'),
#  ('Brian Chandler', 'Mami Nishi', '2155554369'),
#  ('Brian Chandler', 'Yoshimi Kato', '2155554369'),
#  ('Brian Chandler', 'Martin Gerard', '2155554369'),
#  ('Brian Chandler', 'Diane Murphy', '2155554369'),
#  ('Brydey Walker', 'Jeff Firrelli', '+612 9411 1555'),
#  ('Brydey Walker', 'Diane Murphy', '+612 9411 1555'),
#  ('Brydey Walker', 'Martin Gerard', '+612 9411 1555'),
#  ('Brydey Walker', 'Yoshimi Kato', '+612 9411 1555'),
#  ('Brydey Walker', 'Mami Nishi', '+612 9411 1555'),
#  ('Brydey Walker', 'Tom King', '+612 9411 1555'),
#  ('Brydey Walker', 'Peter Marsh', '+612 9411 1555'),
#  ('Brydey Walker', 'Andy Fixter', '+612 9411 1555'),
#  ('Brydey Walker', 'Barry Jones', '+612 9411 1555'),
#  ('Brydey Walker', 'Larry Bott', '+612 9411 1555'),
#  ('Brydey Walker', 'Pamela Castillo', '+612 9411 1555'),
#  ('Brydey Walker', 'Mary Patterson', '+612 9411 1555'),
#  ('Brydey Walker', 'Loui Bondur', '+612 9411 1555'),
#  ('Brydey Walker', 'George Vanauf', '+612 9411 1555'),
#  ('Brydey Walker', 'Foon Yue Tseng', '+612 9411 1555'),
#  ('Brydey Walker', 'Steve Patterson', '+612 9411 1555'),
#  ('Brydey Walker', 'Julie Firrelli', '+612 9411 1555'),
#  ('Brydey Walker', 'Leslie Thompson', '+612 9411 1555'),
#  ('Brydey Walker', 'Leslie Jennings', '+612 9411 1555'),
#  ('Brydey Walker', 'Anthony Bow', '+612 9411 1555'),
#  ('Brydey Walker', 'Gerard Bondur', '+612 9411 1555'),
#  ('Brydey Walker', 'William Patterson', '+612 9411 1555'),
#  ('Brydey Walker', 'Gerard Hernandez', '+612 9411 1555'),
#  ('Carine  Schmitt', 'Martin Gerard', '40.32.2555'),
#  ('Carine  Schmitt', 'Foon Yue Tseng', '40.32.2555'),
#  ('Carine  Schmitt', 'Diane Murphy', '40.32.2555'),
#  ('Carine  Schmitt', 'Mary Patterson', '40.32.2555'),
#  ('Carine  Schmitt', 'Jeff Firrelli', '40.32.2555'),
#  ('Carine  Schmitt', 'William Patterson', '40.32.2555'),
#  ('Carine  Schmitt', 'Gerard Bondur', '40.32.2555'),
#  ('Carine  Schmitt', 'Anthony Bow', '40.32.2555'),
#  ('Carine  Schmitt', 'Leslie Jennings', '40.32.2555'),
#  ('Carine  Schmitt', 'Leslie Thompson', '40.32.2555'),
#  ('Carine  Schmitt', 'Julie Firrelli', '40.32.2555'),
#  ('Carine  Schmitt', 'Steve Patterson', '40.32.2555'),
#  ('Carine  Schmitt', 'George Vanauf', '40.32.2555'),
#  ('Carine  Schmitt', 'Loui Bondur', '40.32.2555'),
#  ('Carine  Schmitt', 'Gerard Hernandez', '40.32.2555'),
#  ('Carine  Schmitt', 'Pamela Castillo', '40.32.2555'),
#  ('Carine  Schmitt', 'Larry Bott', '40.32.2555'),
#  ('Carine  Schmitt', 'Barry Jones', '40.32.2555'),
#  ('Carine  Schmitt', 'Andy Fixter', '40.32.2555'),
#  ('Carine  Schmitt', 'Peter Marsh', '40.32.2555'),
#  ('Carine  Schmitt', 'Tom King', '40.32.2555'),
#  ('Carine  Schmitt', 'Mami Nishi', '40.32.2555'),
#  ('Carine  Schmitt', 'Yoshimi Kato', '40.32.2555'),
#  ('Carmen Anton', 'Martin Gerard', '+34 913 728555'),
#  ('Carmen Anton', 'Diane Murphy', '+34 913 728555'),
#  ('Carmen Anton', 'Yoshimi Kato', '+34 913 728555'),
#  ('Carmen Anton', 'Mami Nishi', '+34 913 728555'),
#  ('Carmen Anton', 'Tom King', '+34 913 728555'),
#  ('Carmen Anton', 'Peter Marsh', '+34 913 728555'),
#  ('Carmen Anton', 'Andy Fixter', '+34 913 728555'),
#  ('Carmen Anton', 'Barry Jones', '+34 913 728555'),
#  ('Carmen Anton', 'Larry Bott', '+34 913 728555'),
#  ('Carmen Anton', 'Pamela Castillo', '+34 913 728555'),
#  ('Carmen Anton', 'Gerard Hernandez', '+34 913 728555'),
#  ('Carmen Anton', 'Loui Bondur', '+34 913 728555'),
#  ('Carmen Anton', 'George Vanauf', '+34 913 728555'),
#  ('Carmen Anton', 'Foon Yue Tseng', '+34 913 728555'),
#  ('Carmen Anton', 'Steve Patterson', '+34 913 728555'),
#  ('Carmen Anton', 'Julie Firrelli', '+34 913 728555'),
#  ('Carmen Anton', 'Leslie Thompson', '+34 913 728555'),
#  ('Carmen Anton', 'Leslie Jennings', '+34 913 728555'),
#  ('Carmen Anton', 'Anthony Bow', '+34 913 728555'),
#  ('Carmen Anton', 'Gerard Bondur', '+34 913 728555'),
#  ('Carmen Anton', 'William Patterson', '+34 913 728555'),
#  ('Carmen Anton', 'Jeff Firrelli', '+34 913 728555'),
#  ('Carmen Anton', 'Mary Patterson', '+34 913 728555'),
#  ('Catherine  Dewey', 'Mary Patterson', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Mami Nishi', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Tom King', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Peter Marsh', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Andy Fixter', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Barry Jones', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Larry Bott', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Pamela Castillo', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Gerard Hernandez', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Loui Bondur', '(02) 5554 67'),
#  ('Catherine  Dewey', 'George Vanauf', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Diane Murphy', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Martin Gerard', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Foon Yue Tseng', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Steve Patterson', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Julie Firrelli', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Leslie Thompson', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Leslie Jennings', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Anthony Bow', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Gerard Bondur', '(02) 5554 67'),
#  ('Catherine  Dewey', 'William Patterson', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Jeff Firrelli', '(02) 5554 67'),
#  ('Catherine  Dewey', 'Yoshimi Kato', '(02) 5554 67'),
#  ('Christina  Berglund', 'George Vanauf', '0921-12 3555'),
#  ('Christina  Berglund', 'Diane Murphy', '0921-12 3555'),
#  ('Christina  Berglund', 'Mary Patterson', '0921-12 3555'),
#  ('Christina  Berglund', 'Jeff Firrelli', '0921-12 3555'),
#  ('Christina  Berglund', 'William Patterson', '0921-12 3555'),
#  ('Christina  Berglund', 'Gerard Bondur', '0921-12 3555'),
#  ('Christina  Berglund', 'Anthony Bow', '0921-12 3555'),
#  ('Christina  Berglund', 'Leslie Jennings', '0921-12 3555'),
#  ('Christina  Berglund', 'Leslie Thompson', '0921-12 3555'),
#  ('Christina  Berglund', 'Julie Firrelli', '0921-12 3555'),
#  ('Christina  Berglund', 'Steve Patterson', '0921-12 3555'),
#  ('Christina  Berglund', 'Foon Yue Tseng', '0921-12 3555'),
#  ('Christina  Berglund', 'Loui Bondur', '0921-12 3555'),
#  ('Christina  Berglund', 'Gerard Hernandez', '0921-12 3555'),
#  ('Christina  Berglund', 'Pamela Castillo', '0921-12 3555'),
#  ('Christina  Berglund', 'Larry Bott', '0921-12 3555'),
#  ('Christina  Berglund', 'Barry Jones', '0921-12 3555'),
#  ('Christina  Berglund', 'Andy Fixter', '0921-12 3555'),
#  ('Christina  Berglund', 'Peter Marsh', '0921-12 3555'),
#  ('Christina  Berglund', 'Tom King', '0921-12 3555'),
#  ('Christina  Berglund', 'Mami Nishi', '0921-12 3555'),
#  ('Christina  Berglund', 'Yoshimi Kato', '0921-12 3555'),
#  ('Christina  Berglund', 'Martin Gerard', '0921-12 3555'),
#  ('Dan Lewis', 'Martin Gerard', '2035554407'),
#  ('Dan Lewis', 'Yoshimi Kato', '2035554407'),
#  ('Dan Lewis', 'Mami Nishi', '2035554407'),
#  ('Dan Lewis', 'Tom King', '2035554407'),
#  ('Dan Lewis', 'Peter Marsh', '2035554407'),
#  ('Dan Lewis', 'Andy Fixter', '2035554407'),
#  ('Dan Lewis', 'Barry Jones', '2035554407'),
#  ('Dan Lewis', 'Larry Bott', '2035554407'),
#  ('Dan Lewis', 'Pamela Castillo', '2035554407'),
#  ('Dan Lewis', 'Gerard Hernandez', '2035554407'),
#  ('Dan Lewis', 'Loui Bondur', '2035554407'),
#  ('Dan Lewis', 'George Vanauf', '2035554407'),
#  ('Dan Lewis', 'Foon Yue Tseng', '2035554407'),
#  ('Dan Lewis', 'Steve Patterson', '2035554407'),
#  ('Dan Lewis', 'Julie Firrelli', '2035554407'),
#  ('Dan Lewis', 'Leslie Thompson', '2035554407'),
#  ('Dan Lewis', 'Leslie Jennings', '2035554407'),
#  ('Dan Lewis', 'Anthony Bow', '2035554407'),
#  ('Dan Lewis', 'Gerard Bondur', '2035554407'),
#  ('Dan Lewis', 'William Patterson', '2035554407'),
#  ('Dan Lewis', 'Jeff Firrelli', '2035554407'),
#  ('Dan Lewis', 'Mary Patterson', '2035554407'),
#  ('Dan Lewis', 'Diane Murphy', '2035554407'),
#  ('Daniel  Tonini', 'Diane Murphy', '30.59.8555'),
#  ('Daniel  Tonini', 'Martin Gerard', '30.59.8555'),
#  ('Daniel  Tonini', 'Yoshimi Kato', '30.59.8555'),
#  ('Daniel  Tonini', 'Mami Nishi', '30.59.8555'),
#  ('Daniel  Tonini', 'Tom King', '30.59.8555'),
#  ('Daniel  Tonini', 'Peter Marsh', '30.59.8555'),
#  ('Daniel  Tonini', 'Andy Fixter', '30.59.8555'),
#  ('Daniel  Tonini', 'Barry Jones', '30.59.8555'),
#  ('Daniel  Tonini', 'Larry Bott', '30.59.8555'),
#  ('Daniel  Tonini', 'Pamela Castillo', '30.59.8555'),
#  ('Daniel  Tonini', 'Gerard Hernandez', '30.59.8555'),
#  ('Daniel  Tonini', 'Loui Bondur', '30.59.8555'),
#  ('Daniel  Tonini', 'George Vanauf', '30.59.8555'),
#  ('Daniel  Tonini', 'Foon Yue Tseng', '30.59.8555'),
#  ('Daniel  Tonini', 'Steve Patterson', '30.59.8555'),
#  ('Daniel  Tonini', 'Julie Firrelli', '30.59.8555'),
#  ('Daniel  Tonini', 'Leslie Thompson', '30.59.8555'),
#  ('Daniel  Tonini', 'Leslie Jennings', '30.59.8555'),
#  ('Daniel  Tonini', 'Anthony Bow', '30.59.8555'),
#  ('Daniel  Tonini', 'Gerard Bondur', '30.59.8555'),
#  ('Daniel  Tonini', 'William Patterson', '30.59.8555'),
#  ('Daniel  Tonini', 'Jeff Firrelli', '30.59.8555'),
#  ('Daniel  Tonini', 'Mary Patterson', '30.59.8555'),
#  ('Daniel Da Silva', 'Diane Murphy', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Martin Gerard', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Yoshimi Kato', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Mami Nishi', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Tom King', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Peter Marsh', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Andy Fixter', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Barry Jones', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Larry Bott', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Pamela Castillo', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Mary Patterson', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Loui Bondur', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'George Vanauf', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Foon Yue Tseng', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Steve Patterson', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Julie Firrelli', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Leslie Thompson', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Leslie Jennings', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Anthony Bow', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Gerard Bondur', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'William Patterson', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Jeff Firrelli', '+33 1 46 62 7555'),
#  ('Daniel Da Silva', 'Gerard Hernandez', '+33 1 46 62 7555'),
#  ('Dean Cassidy', 'George Vanauf', '+353 1862 1555'),
#  ('Dean Cassidy', 'Larry Bott', '+353 1862 1555'),
#  ('Dean Cassidy', 'Martin Gerard', '+353 1862 1555'),
#  ('Dean Cassidy', 'Yoshimi Kato', '+353 1862 1555'),
#  ('Dean Cassidy', 'Mami Nishi', '+353 1862 1555'),
#  ('Dean Cassidy', 'Tom King', '+353 1862 1555'),
#  ('Dean Cassidy', 'Peter Marsh', '+353 1862 1555'),
#  ('Dean Cassidy', 'Andy Fixter', '+353 1862 1555'),
#  ('Dean Cassidy', 'Barry Jones', '+353 1862 1555'),
#  ('Dean Cassidy', 'Pamela Castillo', '+353 1862 1555'),
#  ('Dean Cassidy', 'Gerard Hernandez', '+353 1862 1555'),
#  ('Dean Cassidy', 'Loui Bondur', '+353 1862 1555'),
#  ('Dean Cassidy', 'Foon Yue Tseng', '+353 1862 1555'),
#  ('Dean Cassidy', 'Steve Patterson', '+353 1862 1555'),
#  ('Dean Cassidy', 'Julie Firrelli', '+353 1862 1555'),
#  ('Dean Cassidy', 'Leslie Thompson', '+353 1862 1555'),
#  ('Dean Cassidy', 'Leslie Jennings', '+353 1862 1555'),
#  ('Dean Cassidy', 'Anthony Bow', '+353 1862 1555'),
#  ('Dean Cassidy', 'Gerard Bondur', '+353 1862 1555'),
#  ('Dean Cassidy', 'William Patterson', '+353 1862 1555'),
#  ('Dean Cassidy', 'Jeff Firrelli', '+353 1862 1555'),
#  ('Dean Cassidy', 'Diane Murphy', '+353 1862 1555'),
#  ('Dean Cassidy', 'Mary Patterson', '+353 1862 1555'),
#  ('Diego  Freyre', 'Jeff Firrelli', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Mary Patterson', '(91) 555 94 44'),
#  ('Diego  Freyre', 'William Patterson', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Gerard Bondur', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Anthony Bow', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Leslie Jennings', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Leslie Thompson', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Julie Firrelli', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Steve Patterson', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Foon Yue Tseng', '(91) 555 94 44'),
#  ('Diego  Freyre', 'George Vanauf', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Loui Bondur', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Gerard Hernandez', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Pamela Castillo', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Larry Bott', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Barry Jones', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Andy Fixter', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Peter Marsh', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Tom King', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Mami Nishi', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Yoshimi Kato', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Martin Gerard', '(91) 555 94 44'),
#  ('Diego  Freyre', 'Diane Murphy', '(91) 555 94 44'),
#  ('Dominique Perrier', 'Diane Murphy', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'William Patterson', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Gerard Bondur', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Anthony Bow', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Leslie Jennings', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Leslie Thompson', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Julie Firrelli', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Steve Patterson', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Foon Yue Tseng', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'George Vanauf', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Loui Bondur', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Gerard Hernandez', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Jeff Firrelli', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Pamela Castillo', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Larry Bott', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Barry Jones', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Andy Fixter', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Peter Marsh', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Tom King', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Mami Nishi', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Mary Patterson', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Martin Gerard', '(1) 47.55.6555'),
#  ('Dominique Perrier', 'Yoshimi Kato', '(1) 47.55.6555'),
#  ('Dorothy Young', 'Diane Murphy', '6035558647'),
#  ('Dorothy Young', 'Mary Patterson', '6035558647'),
#  ('Dorothy Young', 'Jeff Firrelli', '6035558647'),
#  ('Dorothy Young', 'William Patterson', '6035558647'),
#  ('Dorothy Young', 'Gerard Bondur', '6035558647'),
#  ('Dorothy Young', 'Anthony Bow', '6035558647'),
#  ('Dorothy Young', 'Leslie Jennings', '6035558647'),
#  ('Dorothy Young', 'Leslie Thompson', '6035558647'),
#  ('Dorothy Young', 'Julie Firrelli', '6035558647'),
#  ('Dorothy Young', 'Steve Patterson', '6035558647'),
#  ('Dorothy Young', 'Foon Yue Tseng', '6035558647'),
#  ('Dorothy Young', 'George Vanauf', '6035558647'),
#  ('Dorothy Young', 'Loui Bondur', '6035558647'),
#  ('Dorothy Young', 'Gerard Hernandez', '6035558647'),
#  ('Dorothy Young', 'Pamela Castillo', '6035558647'),
#  ('Dorothy Young', 'Larry Bott', '6035558647'),
#  ('Dorothy Young', 'Barry Jones', '6035558647'),
#  ('Dorothy Young', 'Andy Fixter', '6035558647'),
#  ('Dorothy Young', 'Peter Marsh', '6035558647'),
#  ('Dorothy Young', 'Tom King', '6035558647'),
#  ('Dorothy Young', 'Mami Nishi', '6035558647'),
#  ('Dorothy Young', 'Yoshimi Kato', '6035558647'),
#  ('Dorothy Young', 'Martin Gerard', '6035558647'),
#  ('Ed Harrison', 'Yoshimi Kato', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Mami Nishi', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Tom King', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Peter Marsh', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Andy Fixter', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Barry Jones', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Larry Bott', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Pamela Castillo', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Gerard Hernandez', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Loui Bondur', '+41 26 425 50 01'),
#  ('Ed Harrison', 'George Vanauf', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Foon Yue Tseng', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Martin Gerard', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Julie Firrelli', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Leslie Thompson', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Leslie Jennings', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Anthony Bow', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Gerard Bondur', '+41 26 425 50 01'),
#  ('Ed Harrison', 'William Patterson', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Jeff Firrelli', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Mary Patterson', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Diane Murphy', '+41 26 425 50 01'),
#  ('Ed Harrison', 'Steve Patterson', '+41 26 425 50 01'),
#  ('Eduardo  Saavedra', 'Mami Nishi', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Yoshimi Kato', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Tom King', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Peter Marsh', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Andy Fixter', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Barry Jones', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Larry Bott', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Pamela Castillo', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Gerard Hernandez', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Loui Bondur', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'George Vanauf', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Foon Yue Tseng', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Steve Patterson', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Julie Firrelli', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Leslie Thompson', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Leslie Jennings', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Anthony Bow', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Gerard Bondur', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'William Patterson', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Jeff Firrelli', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Mary Patterson', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Diane Murphy', '(93) 203 4555'),
#  ('Eduardo  Saavedra', 'Martin Gerard', '(93) 203 4555'),
#  ('Elizabeth  Lincoln', 'Diane Murphy', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Yoshimi Kato', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Jeff Firrelli', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Mary Patterson', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Gerard Bondur', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Anthony Bow', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Leslie Jennings', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Leslie Thompson', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Julie Firrelli', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Steve Patterson', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Foon Yue Tseng', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'George Vanauf', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Martin Gerard', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Loui Bondur', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Gerard Hernandez', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Pamela Castillo', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Larry Bott', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Barry Jones', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Andy Fixter', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Peter Marsh', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Tom King', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'Mami Nishi', '(604) 555-4555'),
#  ('Elizabeth  Lincoln', 'William Patterson', '(604) 555-4555'),
#  ('Elizabeth Devon', 'Mami Nishi', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Tom King', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Peter Marsh', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Andy Fixter', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Barry Jones', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Larry Bott', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Pamela Castillo', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Gerard Hernandez', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Loui Bondur', '(171) 555-2282'),
#  ('Elizabeth Devon', 'George Vanauf', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Foon Yue Tseng', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Yoshimi Kato', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Steve Patterson', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Julie Firrelli', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Leslie Thompson', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Leslie Jennings', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Anthony Bow', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Gerard Bondur', '(171) 555-2282'),
#  ('Elizabeth Devon', 'William Patterson', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Martin Gerard', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Jeff Firrelli', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Mary Patterson', '(171) 555-2282'),
#  ('Elizabeth Devon', 'Diane Murphy', '(171) 555-2282'),
#  ('Eric Natividad', 'Martin Gerard', '+65 221 7555'),
#  ('Eric Natividad', 'Yoshimi Kato', '+65 221 7555'),
#  ('Eric Natividad', 'Diane Murphy', '+65 221 7555'),
#  ('Eric Natividad', 'Mami Nishi', '+65 221 7555'),
#  ('Eric Natividad', 'Tom King', '+65 221 7555'),
#  ('Eric Natividad', 'Peter Marsh', '+65 221 7555'),
#  ('Eric Natividad', 'Andy Fixter', '+65 221 7555'),
#  ('Eric Natividad', 'Barry Jones', '+65 221 7555'),
#  ('Eric Natividad', 'Larry Bott', '+65 221 7555'),
#  ('Eric Natividad', 'Pamela Castillo', '+65 221 7555'),
#  ('Eric Natividad', 'Gerard Hernandez', '+65 221 7555'),
#  ('Eric Natividad', 'Loui Bondur', '+65 221 7555'),
#  ('Eric Natividad', 'George Vanauf', '+65 221 7555'),
#  ('Eric Natividad', 'Foon Yue Tseng', '+65 221 7555'),
#  ('Eric Natividad', 'Steve Patterson', '+65 221 7555'),
#  ('Eric Natividad', 'Julie Firrelli', '+65 221 7555'),
#  ('Eric Natividad', 'Leslie Thompson', '+65 221 7555'),
#  ('Eric Natividad', 'Leslie Jennings', '+65 221 7555'),
#  ('Eric Natividad', 'Anthony Bow', '+65 221 7555'),
#  ('Eric Natividad', 'Jeff Firrelli', '+65 221 7555'),
#  ('Eric Natividad', 'William Patterson', '+65 221 7555'),
#  ('Eric Natividad', 'Mary Patterson', '+65 221 7555'),
#  ('Eric Natividad', 'Gerard Bondur', '+65 221 7555'),
#  ('Francisca Cervantes', 'Diane Murphy', '2155554695'),
#  ('Francisca Cervantes', 'Mary Patterson', '2155554695'),
#  ('Francisca Cervantes', 'Jeff Firrelli', '2155554695'),
#  ('Francisca Cervantes', 'William Patterson', '2155554695'),
#  ('Francisca Cervantes', 'Gerard Bondur', '2155554695'),
#  ('Francisca Cervantes', 'Anthony Bow', '2155554695'),
#  ('Francisca Cervantes', 'Leslie Jennings', '2155554695'),
#  ('Francisca Cervantes', 'Leslie Thompson', '2155554695'),
#  ('Francisca Cervantes', 'Julie Firrelli', '2155554695'),
#  ('Francisca Cervantes', 'Steve Patterson', '2155554695'),
#  ('Francisca Cervantes', 'Foon Yue Tseng', '2155554695'),
#  ('Francisca Cervantes', 'George Vanauf', '2155554695'),
#  ('Francisca Cervantes', 'Gerard Hernandez', '2155554695'),
#  ('Francisca Cervantes', 'Pamela Castillo', '2155554695'),
#  ('Francisca Cervantes', 'Larry Bott', '2155554695'),
#  ('Francisca Cervantes', 'Barry Jones', '2155554695'),
#  ('Francisca Cervantes', 'Andy Fixter', '2155554695'),
#  ('Francisca Cervantes', 'Peter Marsh', '2155554695'),
#  ('Francisca Cervantes', 'Tom King', '2155554695'),
#  ('Francisca Cervantes', 'Mami Nishi', '2155554695'),
#  ('Francisca Cervantes', 'Yoshimi Kato', '2155554695'),
#  ('Francisca Cervantes', 'Martin Gerard', '2155554695'),
#  ('Francisca Cervantes', 'Loui Bondur', '2155554695'),
#  ('Franco Ricotti', 'Yoshimi Kato', '+39 022515555'),
#  ('Franco Ricotti', 'Mami Nishi', '+39 022515555'),
#  ('Franco Ricotti', 'Tom King', '+39 022515555'),
#  ('Franco Ricotti', 'Peter Marsh', '+39 022515555'),
#  ('Franco Ricotti', 'Andy Fixter', '+39 022515555'),
#  ('Franco Ricotti', 'Barry Jones', '+39 022515555'),
#  ('Franco Ricotti', 'Larry Bott', '+39 022515555'),
#  ('Franco Ricotti', 'Pamela Castillo', '+39 022515555'),
#  ('Franco Ricotti', 'Gerard Hernandez', '+39 022515555'),
#  ('Franco Ricotti', 'Loui Bondur', '+39 022515555'),
#  ('Franco Ricotti', 'George Vanauf', '+39 022515555'),
#  ('Franco Ricotti', 'Martin Gerard', '+39 022515555'),
#  ('Franco Ricotti', 'Steve Patterson', '+39 022515555'),
#  ('Franco Ricotti', 'Julie Firrelli', '+39 022515555'),
#  ('Franco Ricotti', 'Leslie Thompson', '+39 022515555'),
#  ('Franco Ricotti', 'Leslie Jennings', '+39 022515555'),
#  ('Franco Ricotti', 'Anthony Bow', '+39 022515555'),
#  ('Franco Ricotti', 'Gerard Bondur', '+39 022515555'),
#  ('Franco Ricotti', 'William Patterson', '+39 022515555'),
#  ('Franco Ricotti', 'Jeff Firrelli', '+39 022515555'),
#  ('Franco Ricotti', 'Mary Patterson', '+39 022515555'),
#  ('Franco Ricotti', 'Diane Murphy', '+39 022515555'),
#  ('Franco Ricotti', 'Foon Yue Tseng', '+39 022515555'),
#  ('Frédérique  Citeaux', 'Martin Gerard', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Yoshimi Kato', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Mami Nishi', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Tom King', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Peter Marsh', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Andy Fixter', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Barry Jones', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Larry Bott', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Pamela Castillo', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Gerard Hernandez', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Loui Bondur', '88.60.1555'),
#  ('Frédérique  Citeaux', 'George Vanauf', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Foon Yue Tseng', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Steve Patterson', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Julie Firrelli', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Leslie Thompson', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Leslie Jennings', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Anthony Bow', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Gerard Bondur', '88.60.1555'),
#  ('Frédérique  Citeaux', 'William Patterson', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Jeff Firrelli', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Mary Patterson', '88.60.1555'),
#  ('Frédérique  Citeaux', 'Diane Murphy', '88.60.1555'),
#  ('Georg  Pipps', 'Mary Patterson', '6562-9555'),
#  ('Georg  Pipps', 'Yoshimi Kato', '6562-9555'),
#  ('Georg  Pipps', 'Diane Murphy', '6562-9555'),
#  ('Georg  Pipps', 'Mami Nishi', '6562-9555'),
#  ('Georg  Pipps', 'Tom King', '6562-9555'),
#  ('Georg  Pipps', 'Peter Marsh', '6562-9555'),
#  ('Georg  Pipps', 'Andy Fixter', '6562-9555'),
#  ('Georg  Pipps', 'Barry Jones', '6562-9555'),
#  ('Georg  Pipps', 'Larry Bott', '6562-9555'),
#  ('Georg  Pipps', 'Pamela Castillo', '6562-9555'),
#  ('Georg  Pipps', 'Gerard Hernandez', '6562-9555'),
#  ('Georg  Pipps', 'Loui Bondur', '6562-9555'),
#  ('Georg  Pipps', 'George Vanauf', '6562-9555'),
#  ('Georg  Pipps', 'Foon Yue Tseng', '6562-9555'),
#  ('Georg  Pipps', 'Steve Patterson', '6562-9555'),
#  ('Georg  Pipps', 'Julie Firrelli', '6562-9555'),
#  ('Georg  Pipps', 'Leslie Thompson', '6562-9555'),
#  ('Georg  Pipps', 'Leslie Jennings', '6562-9555'),
#  ('Georg  Pipps', 'Anthony Bow', '6562-9555'),
#  ('Georg  Pipps', 'Gerard Bondur', '6562-9555'),
#  ('Georg  Pipps', 'William Patterson', '6562-9555'),
#  ('Georg  Pipps', 'Jeff Firrelli', '6562-9555'),
#  ('Georg  Pipps', 'Martin Gerard', '6562-9555'),
#  ('Giovanni  Rovelli', 'Anthony Bow', '035-640555'),
#  ('Giovanni  Rovelli', 'George Vanauf', '035-640555'),
#  ('Giovanni  Rovelli', 'Diane Murphy', '035-640555'),
#  ('Giovanni  Rovelli', 'Mary Patterson', '035-640555'),
#  ('Giovanni  Rovelli', 'Jeff Firrelli', '035-640555'),
#  ('Giovanni  Rovelli', 'William Patterson', '035-640555'),
#  ('Giovanni  Rovelli', 'Gerard Bondur', '035-640555'),
#  ('Giovanni  Rovelli', 'Leslie Jennings', '035-640555'),
#  ('Giovanni  Rovelli', 'Leslie Thompson', '035-640555'),
#  ('Giovanni  Rovelli', 'Julie Firrelli', '035-640555'),
#  ('Giovanni  Rovelli', 'Steve Patterson', '035-640555'),
#  ('Giovanni  Rovelli', 'Foon Yue Tseng', '035-640555'),
#  ('Giovanni  Rovelli', 'Loui Bondur', '035-640555'),
#  ('Giovanni  Rovelli', 'Gerard Hernandez', '035-640555'),
#  ('Giovanni  Rovelli', 'Pamela Castillo', '035-640555'),
#  ('Giovanni  Rovelli', 'Larry Bott', '035-640555'),
#  ('Giovanni  Rovelli', 'Barry Jones', '035-640555'),
#  ('Giovanni  Rovelli', 'Andy Fixter', '035-640555'),
#  ('Giovanni  Rovelli', 'Peter Marsh', '035-640555'),
#  ('Giovanni  Rovelli', 'Tom King', '035-640555'),
#  ('Giovanni  Rovelli', 'Mami Nishi', '035-640555'),
#  ('Giovanni  Rovelli', 'Yoshimi Kato', '035-640555'),
#  ('Giovanni  Rovelli', 'Martin Gerard', '035-640555'),
#  ('Hanna  Moos', 'Diane Murphy', '0621-08555'),
#  ('Hanna  Moos', 'Mary Patterson', '0621-08555'),
#  ('Hanna  Moos', 'Jeff Firrelli', '0621-08555'),
#  ('Hanna  Moos', 'William Patterson', '0621-08555'),
#  ('Hanna  Moos', 'Gerard Bondur', '0621-08555'),
#  ('Hanna  Moos', 'Anthony Bow', '0621-08555'),
#  ('Hanna  Moos', 'Leslie Jennings', '0621-08555'),
#  ('Hanna  Moos', 'Leslie Thompson', '0621-08555'),
#  ('Hanna  Moos', 'Julie Firrelli', '0621-08555'),
#  ('Hanna  Moos', 'Steve Patterson', '0621-08555'),
#  ('Hanna  Moos', 'Foon Yue Tseng', '0621-08555'),
#  ('Hanna  Moos', 'George Vanauf', '0621-08555'),
#  ('Hanna  Moos', 'Loui Bondur', '0621-08555'),
#  ('Hanna  Moos', 'Gerard Hernandez', '0621-08555'),
#  ('Hanna  Moos', 'Pamela Castillo', '0621-08555'),
#  ('Hanna  Moos', 'Larry Bott', '0621-08555'),
#  ('Hanna  Moos', 'Barry Jones', '0621-08555'),
#  ('Hanna  Moos', 'Andy Fixter', '0621-08555'),
#  ('Hanna  Moos', 'Peter Marsh', '0621-08555'),
#  ('Hanna  Moos', 'Tom King', '0621-08555'),
#  ('Hanna  Moos', 'Mami Nishi', '0621-08555'),
#  ('Hanna  Moos', 'Yoshimi Kato', '0621-08555'),
#  ('Hanna  Moos', 'Martin Gerard', '0621-08555'),
#  ('Helen  Bennett', 'Yoshimi Kato', '(198) 555-8888'),
#  ('Helen  Bennett', 'Mami Nishi', '(198) 555-8888'),
#  ('Helen  Bennett', 'Tom King', '(198) 555-8888'),
#  ('Helen  Bennett', 'Peter Marsh', '(198) 555-8888'),
#  ('Helen  Bennett', 'Andy Fixter', '(198) 555-8888'),
#  ('Helen  Bennett', 'Barry Jones', '(198) 555-8888'),
#  ('Helen  Bennett', 'Larry Bott', '(198) 555-8888'),
#  ('Helen  Bennett', 'Pamela Castillo', '(198) 555-8888'),
#  ('Helen  Bennett', 'Gerard Hernandez', '(198) 555-8888'),
#  ('Helen  Bennett', 'Loui Bondur', '(198) 555-8888'),
#  ('Helen  Bennett', 'George Vanauf', '(198) 555-8888'),
#  ('Helen  Bennett', 'Foon Yue Tseng', '(198) 555-8888'),
#  ('Helen  Bennett', 'Steve Patterson', '(198) 555-8888'),
#  ('Helen  Bennett', 'Julie Firrelli', '(198) 555-8888'),
#  ('Helen  Bennett', 'Leslie Thompson', '(198) 555-8888'),
#  ('Helen  Bennett', 'Leslie Jennings', '(198) 555-8888'),
#  ('Helen  Bennett', 'Anthony Bow', '(198) 555-8888'),
#  ('Helen  Bennett', 'Gerard Bondur', '(198) 555-8888'),
#  ('Helen  Bennett', 'William Patterson', '(198) 555-8888'),
#  ('Helen  Bennett', 'Jeff Firrelli', '(198) 555-8888'),
#  ('Helen  Bennett', 'Mary Patterson', '(198) 555-8888'),
#  ('Helen  Bennett', 'Martin Gerard', '(198) 555-8888'),
#  ('Helen  Bennett', 'Diane Murphy', '(198) 555-8888'),
#  ('Henriette  Pfalzheim', 'Yoshimi Kato', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Mami Nishi', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Mary Patterson', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Jeff Firrelli', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'William Patterson', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Gerard Bondur', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Anthony Bow', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Leslie Jennings', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Leslie Thompson', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Julie Firrelli', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Steve Patterson', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Foon Yue Tseng', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Martin Gerard', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'George Vanauf', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Diane Murphy', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Loui Bondur', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Gerard Hernandez', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Pamela Castillo', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Larry Bott', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Barry Jones', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Andy Fixter', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Peter Marsh', '0221-5554327'),
#  ('Henriette  Pfalzheim', 'Tom King', '0221-5554327'),
#  ('Horst  Kloss', 'Yoshimi Kato', '0372-555188'),
#  ('Horst  Kloss', 'Mami Nishi', '0372-555188'),
#  ('Horst  Kloss', 'Martin Gerard', '0372-555188'),
#  ('Horst  Kloss', 'Tom King', '0372-555188'),
#  ('Horst  Kloss', 'Peter Marsh', '0372-555188'),
#  ('Horst  Kloss', 'Andy Fixter', '0372-555188'),
#  ('Horst  Kloss', 'Barry Jones', '0372-555188'),
#  ('Horst  Kloss', 'Larry Bott', '0372-555188'),
#  ('Horst  Kloss', 'Pamela Castillo', '0372-555188'),
#  ('Horst  Kloss', 'Gerard Hernandez', '0372-555188'),
#  ('Horst  Kloss', 'Loui Bondur', '0372-555188'),
#  ('Horst  Kloss', 'George Vanauf', '0372-555188'),
#  ('Horst  Kloss', 'Steve Patterson', '0372-555188'),
#  ('Horst  Kloss', 'Julie Firrelli', '0372-555188'),
#  ('Horst  Kloss', 'Leslie Thompson', '0372-555188'),
#  ('Horst  Kloss', 'Leslie Jennings', '0372-555188'),
#  ('Horst  Kloss', 'Anthony Bow', '0372-555188'),
#  ('Horst  Kloss', 'Gerard Bondur', '0372-555188'),
#  ('Horst  Kloss', 'William Patterson', '0372-555188'),
#  ('Horst  Kloss', 'Jeff Firrelli', '0372-555188'),
#  ('Horst  Kloss', 'Mary Patterson', '0372-555188'),
#  ('Horst  Kloss', 'Diane Murphy', '0372-555188'),
#  ('Horst  Kloss', 'Foon Yue Tseng', '0372-555188'),
#  ('Isabel  de Castro', 'Mary Patterson', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Jeff Firrelli', '(1) 356-5555'),
#  ('Isabel  de Castro', 'William Patterson', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Gerard Bondur', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Anthony Bow', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Leslie Jennings', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Leslie Thompson', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Julie Firrelli', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Steve Patterson', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Foon Yue Tseng', '(1) 356-5555'),
#  ('Isabel  de Castro', 'George Vanauf', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Loui Bondur', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Gerard Hernandez', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Pamela Castillo', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Larry Bott', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Barry Jones', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Andy Fixter', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Peter Marsh', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Tom King', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Mami Nishi', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Yoshimi Kato', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Martin Gerard', '(1) 356-5555'),
#  ('Isabel  de Castro', 'Diane Murphy', '(1) 356-5555'),
#  ('Jan Klaeboe', 'George Vanauf', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Diane Murphy', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Mary Patterson', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Jeff Firrelli', '+47 2212 1555'),
#  ('Jan Klaeboe', 'William Patterson', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Gerard Bondur', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Anthony Bow', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Leslie Jennings', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Leslie Thompson', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Julie Firrelli', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Steve Patterson', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Foon Yue Tseng', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Martin Gerard', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Loui Bondur', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Gerard Hernandez', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Pamela Castillo', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Larry Bott', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Barry Jones', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Andy Fixter', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Peter Marsh', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Tom King', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Mami Nishi', '+47 2212 1555'),
#  ('Jan Klaeboe', 'Yoshimi Kato', '+47 2212 1555'),
#  ('Janine  Labrune', 'Mary Patterson', '40.67.8555'),
#  ('Janine  Labrune', 'Jeff Firrelli', '40.67.8555'),
#  ('Janine  Labrune', 'William Patterson', '40.67.8555'),
#  ('Janine  Labrune', 'Gerard Bondur', '40.67.8555'),
#  ('Janine  Labrune', 'Anthony Bow', '40.67.8555'),
#  ('Janine  Labrune', 'Leslie Jennings', '40.67.8555'),
#  ('Janine  Labrune', 'Leslie Thompson', '40.67.8555'),
#  ('Janine  Labrune', 'Julie Firrelli', '40.67.8555'),
#  ('Janine  Labrune', 'Steve Patterson', '40.67.8555'),
#  ('Janine  Labrune', 'Foon Yue Tseng', '40.67.8555'),
#  ('Janine  Labrune', 'George Vanauf', '40.67.8555'),
#  ...]

# %% [markdown]
# ## SQL 2

# %% [markdown]
# This query uses `employees`, `customers`, `orders`, `orderdetails`.
#
# Write and execute a SQL query that produces a table showing the amount of money each sales rep has generated.
#
# Your table should have the following columns:
#
# - `salesRepName`
# - `moneyGenerated`
#
# Order your output from greatest to least `moneyGenerated`.
#
# Notes:
# - The names of your columns must match exactly with what is specified.
# - `salesRepName` can be formed by combining `employees.firstName` and `employees.lastName`.
# - To calculate `moneyGenerated`:
#     - Every order in `orders` is associated with multiple rows in `orderdetails`. The total amount of money spent on an order is the sum of `quantityOrdered * priceEach` for all the associated rows in `orderdetails`. **Only consider orders that are `Shipped`.**
#     - A customer can have multiple orders. The total amount of money a customer has spent is the sum of the money spent on all that customer's orders.
#     - A sales rep can have multiple customers. `moneyGenerated` is the sum of the money spent by all that sales rep's customers.
# - You may find the [WITH keyword](https://www.tutorialspoint.com/mysql/mysql_with.htm) to be useful for cleaner code.

# %%
# %%sql
#
# WITH OrderAmounts AS (
#     SELECT
#         o.customerNumber,
#         SUM(od.quantityOrdered * od.priceEach) AS orderTotal
#     FROM orders o
#     JOIN orderdetails od ON o.orderNumber = od.orderNumber
#     WHERE o.status = 'Shipped'
#     GROUP BY o.orderNumber
# ),
# CustomerTotals AS (
#     SELECT
#         c.salesRepEmployeeNumber,
#         SUM(oa.orderTotal) AS customerTotal
#     FROM OrderAmounts oa
#     JOIN customers c ON oa.customerNumber = c.customerNumber
#     GROUP BY c.salesRepEmployeeNumber
# )
# SELECT
#     CONCAT(e.firstName, ' ', e.lastName) AS salesRepName,
#     SUM(ct.customerTotal) AS moneyGenerated
# FROM CustomerTotals ct
# JOIN employees e ON ct.salesRepEmployeeNumber = e.employeeNumber
# GROUP BY e.employeeNumber
# ORDER BY moneyGenerated DESC;
# Out:
#  * mysql+pymysql://root:***@localhost
# 15 rows affected.
# [('Gerard Hernandez', Decimal('1065035.29')),
#  ('Leslie Jennings', Decimal('1021661.89')),
#  ('Pamela Castillo', Decimal('790297.44')),
#  ('Larry Bott', Decimal('686653.25')),
#  ('Barry Jones', Decimal('637672.65')),
#  ('George Vanauf', Decimal('584406.80')),
#  ('Loui Bondur', Decimal('569485.75')),
#  ('Peter Marsh', Decimal('523860.78')),
#  ('Andy Fixter', Decimal('509385.82')),
#  ('Foon Yue Tseng', Decimal('488212.67')),
#  ('Mami Nishi', Decimal('457110.07')),
#  ('Steve Patterson', Decimal('449219.13')),
#  ('Martin Gerard', Decimal('387477.47')),
#  ('Julie Firrelli', Decimal('386663.20')),
#  ('Leslie Thompson', Decimal('307952.43'))]
